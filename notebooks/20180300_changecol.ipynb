# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cd ..
# Out:
# /home/schlecker/repos/planeteScripts

# %%
import make_list

# %%
simlistfile = '../../phd/planete/zubehoer/simulation_list.dat_chris_trappist1'
simlist = make_list.read_simlist(simlistfile)
simlist
# Out:
#              CDnumber         fgp       diskM  a_in      a_out  expo  \
# 0      00000000000000   66.048597   86.861023  0.01  24.003541   0.9
# 1      00000000000000   34.500645   70.398081  0.01  15.766928   0.9
# 2      00000000000000   46.748213   71.123910  0.01  16.093729   0.9
# 3      00000000000000   27.911189   61.264104  0.01  11.940915   0.9
# 4      00000000000000   47.475460   97.841261  0.01  30.455766   0.9
# 5      00000000000000   27.913642   87.962468  0.01  24.616157   0.9
# 6      00000000000000   64.771934   36.295273  0.01   4.191076   0.9
# 7      00000000000000  112.431160   64.634013  0.01  13.290695   0.9
# 8      00000000000000   61.050006   62.333167  0.01  12.361290   0.9
# 9      00000000000000   48.904818   65.700693  0.01  13.732997   0.9
# 10     00000000000000   25.895724   64.473314  0.01  13.224688   0.9
# 11     00000000000000   30.208785   76.004268  0.01  18.378133   0.9
# 12     00000000000000   31.010241   56.534929  0.01  10.168552   0.9
# ...

# %%
import os

# %%
os.listdir()
np.random.rand?

# %%
constFun = lambda x : 2e5
# Out:
# 200000.0

# %%
newlist = make_list.changeListCol(simlist,'t_start', constFun, None)

# %%
make_list.write_simlist('../../phd/planete/zubehoer/simulation_list.dat_t_start2e5', simlist)
# Out:
# 99999 simulations written to "../../phd/planete/zubehoer/simulation_list.dat_t_start2e5".
