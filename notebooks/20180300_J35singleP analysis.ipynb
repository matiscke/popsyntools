# %%
from planeteOutput import *

# %%
hd5file = '/home/schlecker/phd/planete/outputs/J35/J35singlePlanet.hd5'
J35 = read_popHdf5(hd5file)
J35
# Out:
# /SIM0001 (Group) ''
# /SIM0002 (Group) ''
# {'SIM0001': <class 'pandas.core.panel.Panel'>
#  Dimensions: 1 (items) x 3487 (major_axis) x 118 (minor_axis)
#  Items axis: planet_001 to planet_001
#  Major_axis axis: 0 to 3486
#  Minor_axis axis: n to planetNo, 'SIM0002': <class 'pandas.core.panel.Panel'>
#  Dimensions: 1 (items) x 31843 (major_axis) x 118 (minor_axis)
#  Items axis: planet_001 to planet_001
#  Major_axis axis: 0 to 31842
#  Minor_axis axis: n to planetNo}

# %%
J35['SIM0002']['planet_001']
# Out:
#              n             t     mCore          menv         m           L  \
# 0          1.0  2.000149e+05  0.010107  1.000000e-08  0.010107  565.202370
# 1          2.0  2.000291e+05  0.010208  1.000000e-08  0.010208    6.630024
# 2          3.0  2.000433e+05  0.010311  1.000000e-08  0.010311    6.708085
# 3          4.0  2.000576e+05  0.010414  1.000000e-08  0.010414    6.786531
# 4          5.0  2.000719e+05  0.010519  1.000000e-08  0.010519    6.866030
# 5          6.0  2.000864e+05  0.010625  1.000000e-08  0.010625    9.231038
# 6          7.0  2.001009e+05  0.010732  1.000000e-08  0.010732    9.338568
# 7          8.0  2.001154e+05  0.010839  1.000000e-08  0.010839    9.448124
# 8          9.0  2.001301e+05  0.010948  1.000000e-08  0.010948    9.558912
# 9         10.0  2.001448e+05  0.011058  1.000000e-08  0.011058    9.670890
# 10        11.0  2.001596e+05  0.011170  1.000000e-08  0.011170    9.784033
# ...
